# %% [markdown]
# <a href="https://colab.research.google.com/github/bennethobiageri/Data_Engineering_start_up/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HEllo world")
# Out:
# HEllo world
